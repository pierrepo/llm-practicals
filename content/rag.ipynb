# %% [markdown]
# # Simple RAG system
#
# RAG stands for Retrieval-Augmented Generation. Its one method to reduce hallucination while focusing an LLM on specific set of documents.
#
# In this notebook, you will a very basic RAG, without a proper database or user interface.
#
# ## Setup

# %%
from IPython.display import Markdown, display; display(Markdown("env_instructions.md"))
# Out:
# From university computers, use the Conda environment `ppoulain-llm-24`:
#
# ```bash
# $ conda activate ppoulain-llm-24
# ```
#
# You can also try to create this environement on your own computer.
#
# Either with [Miniconda](https://docs.anaconda.com/miniconda/):
#
# ```bash
# $ mkdir -p llm-practicals
# $ cd llm-practicals
# $ curl https://raw.githubusercontent.com/pierrepo/llm-practicals/main/content/practical-env.yml --output practical-env.yml
# # or wget https://raw.githubusercontent.com/pierrepo/llm-practicals/main/content/practical-env.yml
# $ conda env create -f practical-env.yml
# $ conda activate ppoulain-llm-24
# $ jupyter lab
# ```
#
# or with [Pixi](https://pixi.sh):
#
# ```bash
# $ mkdir -p llm-practicals
# $ cd llm-practicals
# $ curl https://raw.githubusercontent.com/pierrepo/llm-practicals/main/content/practical-env.yml --output practical-env.yml
# # or wget https://raw.githubusercontent.com/pierrepo/llm-practicals/main/content/practical-env.yml
# $ pixi init --import practical-env.yml
# $ pixi run jupyter lab
# ```

# %% [markdown]
# ## Data preparation
#
# In this example, you will use the [Gromacs Reference Manual](https://manual.gromacs.org/2024.3/reference-manual/index.html) as the source document for your RAG. Gromacs is a molecular dynamics package mainly designed for simulations of biomolecules.
#
# The Gromacs Reference Manual is available as a set of HTML files. Here is the code I used to download these files and convert them to Markdown. Do not run this code yourself:

# %%
# !python prepare_rag_docs.py
# Out:
# Found 76 urls
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/normal-mode-analysis.html
# Saving to normal-mode-analysis.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/radius-of-gyration.html
# Saving to radius-of-gyration.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/looking-at-trajectory.html
# Saving to looking-at-trajectory.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/topologies/force-field-organization.html
# Saving to force-field-organization.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/algorithms.html
# Saving to algorithms.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/group-concept.html
# Saving to group-concept.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/correlation-function.html
# Saving to correlation-function.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/periodic-boundary-conditions.html
# Saving to periodic-boundary-conditions.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/awh.html
# Saving to awh.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/replica-exchange.html
# Saving to replica-exchange.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/details.html
# Saving to details.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/parallelization-domain-decomp.html
# Saving to parallelization-domain-decomp.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/functions/free-energy-interactions.html
# Saving to free-energy-interactions.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/expanded-ensemble.html
# Saving to expanded-ensemble.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/functions/long-range-vdw.html
# Saving to long-range-vdw.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/topologies/constraint-algorithm-section.html
# Saving to constraint-algorithm-section.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/functions/restraints.html
# Saving to restraints.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/vmd-imd.html
# Saving to vmd-imd.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/references.html
# Saving to references.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/comp-electrophys.html
# Saving to comp-electrophys.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/shearing.html
# Saving to shearing.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/topologies/topology-file-formats.html
# Saving to topology-file-formats.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/functions/long-range-electrostatics.html
# Saving to long-range-electrostatics.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/topologies/pdb2gmx-input-files.html
# Saving to pdb2gmx-input-files.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/file-formats.html
# Saving to file-formats.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/preface.html
# Saving to preface.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/functions/functions.html
# Saving to functions.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/topologies/molecule-definition.html
# Saving to molecule-definition.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/covariance-analysis.html
# Saving to covariance-analysis.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/simulated-annealing.html
# Saving to simulated-annealing.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/mimic-qmmm.html
# Saving to mimic-qmmm.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/general-properties.html
# Saving to general-properties.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/free-energy-calculations.html
# Saving to free-energy-calculations.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/analysis.html
# Saving to analysis.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/enforced-rotation.html
# Saving to enforced-rotation.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/constraint-algorithms.html
# Saving to constraint-algorithms.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/definitions.html
# Saving to definitions.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/functions/bonded-interactions.html
# Saving to bonded-interactions.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/protein-related.html
# Saving to protein-related.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/rmsd.html
# Saving to rmsd.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/interface-related.html
# Saving to interface-related.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/functions/polarization.html
# Saving to polarization.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/colvars.html
# Saving to colvars.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/topologies/particle-type.html
# Saving to particle-type.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/density-guided-simulation.html
# Saving to density-guided-simulation.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/functions/interaction-methods.html
# Saving to interaction-methods.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/qmmm.html
# Saving to qmmm.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/using-groups.html
# Saving to using-groups.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/pulling.html
# Saving to pulling.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/special.html
# Saving to special.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/dihedral-pca.html
# Saving to dihedral-pca.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/hydrogen-bonds.html
# Saving to hydrogen-bonds.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/electric-fields.html
# Saving to electric-fields.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/radial-distribution-function.html
# Saving to radial-distribution-function.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/stochastic-dynamics.html
# Saving to stochastic-dynamics.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/mean-square-displacement.html
# Saving to mean-square-displacement.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/functions/nonbonded-interactions.html
# Saving to nonbonded-interactions.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/bond-angle-dihedral.html
# Saving to bond-angle-dihedral.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/free-energy-implementation.html
# Saving to free-energy-implementation.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/topologies/parameter-files.html
# Saving to parameter-files.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/averages.html
# Saving to averages.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/molecular-dynamics.html
# Saving to molecular-dynamics.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/analysis/curve-fitting.html
# Saving to curve-fitting.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/tabulated-interaction-functions.html
# Saving to tabulated-interaction-functions.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/free-energy-pmf.html
# Saving to free-energy-pmf.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/brownian-dynamics.html
# Saving to brownian-dynamics.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/topologies/topologies.html
# Saving to topologies.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/viscosity-calculation.html
# Saving to viscosity-calculation.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/run-parameters.html
# Saving to run-parameters.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/remove-fast-dgf.html
# Saving to remove-fast-dgf.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/special/membrane-embedding.html
# Saving to membrane-embedding.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/functions/force-field.html
# Saving to force-field.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/introduction.html
# Saving to introduction.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/essential-dynamics.html
# Saving to essential-dynamics.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/energy-minimization.html
# Saving to energy-minimization.md
# Downloading https://manual.gromacs.org/2024.3/reference-manual/algorithms/shell-molecular-dynamics.html
# Saving to shell-molecular-dynamics.md
